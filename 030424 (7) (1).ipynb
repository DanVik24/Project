# %% [markdown]
# # Исследование объявлений о продаже квартир
# ## Цель исследования:
#         Провести иследование данных о квартирах в Иркутске предоставленных сайтом Циан.
# ## Задачи исследования:
#         Доказать, что цена за квадратный метр зависит от района продажи квартиры
# ## Декомпозиция работы:
#         1. Подготовка данных
#         2. Предобработка данных
#         3. Анализ данных
#         4. Визуализация данных
#         5. Вывод о задачах исследования

# %% [markdown]
# ### 1. Подготовка данных

# %%
#Импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
# импорт библиотек для отоброжения графика на гитхаб
import plotly.io as pio
pio.renderers.default='notebook'

#показать всю информацию в колонках 
pd.set_option('display.max_colwidth', None)

#Загружаем данные 
data = pd.read_csv('C:/Users/admin/all/flat_3.csv', sep=';')

display(data.head())
# Out:
#           ID Количество комнат                             Тип         район  \
# 0  300151528                 2  Продажа квартиры в новостройке  Свердловский
# 1  297027698                 2                Продажа квартиры  Свердловский
# 2  300140904   2, Аппартаменты                Продажа квартиры  Свердловский
# 3  295915593                 1                Продажа квартиры  Свердловский
# 4  295895678                 3  Продажа квартиры в новостройке  Свердловский
#
#                                                  Адрес  Площадь, м2   Этаж  \
# 0          Иркутская область, Иркутск, улица Костычева         34.8   4/12
# 1   Иркутская область, Иркутск, улица Помяловского, 30         48.0    5/5
# 2      Иркутская область, Иркутск, улица Сергеева, 5/8         58.7    2/4
# 3  Иркутская область, Иркутск, улица Багратиона, 54/11         43.0    7/9
# 4          Иркутская область, Иркутск, улица Костычева         66.1  12/12
#
#       Цена         Ремонт                     Ссылка на объявление
# 0  5220000            NaN  https://www.cian.ru/sale/flat/300151528
# 1  4450000  Косметический  https://www.cian.ru/sale/flat/297027698
# 2  5700000     Евроремонт  https://www.cian.ru/sale/flat/300140904
# 3  5990000  Косметический  https://www.cian.ru/sale/flat/295915593
# 4  7204900            NaN  https://www.cian.ru/sale/flat/295895678

# %%
# переименование столбцов для удобного использования 
data = data.rename(columns={'Количество комнат': 'rooms', 
                               'Тип': 'type', 
                               'район': 'district', 
                               'Адрес': 'address', 
                               'Площадь, м2': 'area',
                               'Этаж': 'floor', 
                               'Цена': 'price', 
                               'Ремонт': 'repair', 
                               'Ссылка на объявление': 'link'})
# смотрим основную информацию о датафрейме
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 763 entries, 0 to 762
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        763 non-null    int64
#  1   rooms     742 non-null    object
#  2   type      763 non-null    object
#  3   district  763 non-null    object
#  4   address   763 non-null    object
#  5   area      763 non-null    float64
#  6   floor     763 non-null    object
#  7   price     763 non-null    int64
#  8   repair    86 non-null     object
#  9   link      763 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 59.7+ KB
# None

# %%
# просмотр уникальных данных в столбцах:
display(data['rooms'].unique())
display(data['type'].unique())
display(data['district'].unique())
display(data['repair'].unique())
# Out:
# array(['2', '2, Аппартаменты', '1', '3', nan, '4', '2, Изолированная',
#        '2, Смежная', '3, Изолированная', '5', '4, Смежная',
#        '2, Оба варианта', '2, Изолированная, Аппартаменты',
#        '3, Оба варианта', '3, Смежная', '4, Изолированная'], dtype=object)
# array(['Продажа квартиры в новостройке', 'Продажа квартиры'], dtype=object)
# array(['Свердловский', 'Правобережный', 'Октябрьский', 'Ленинский'],
#       dtype=object)
# array([nan, 'Косметический', 'Евроремонт', 'Дизайнерский', 'Без ремонта'],
#       dtype=object)

# %%
# изменим столбец с данными о колве квартир - уберем лишнюю информацию
data['rooms'] = data['rooms'].str.replace(',', ' ').str.replace('\D', '', regex=True) # удаляет данные в ячейке после ","
data.sample(5)
# Out:
#             ID rooms                            type      district  \
# 508  298600132     1  Продажа квартиры в новостройке   Октябрьский
# 671  296464654     1  Продажа квартиры в новостройке     Ленинский
# 43   295895639     3  Продажа квартиры в новостройке  Свердловский
# 51   293746937     1  Продажа квартиры в новостройке  Свердловский
# 140  300151520     2  Продажа квартиры в новостройке  Свердловский
#
#                                                                  address  \
# 508                            Иркутская область, Иркутск, ИВАТУ городок
# 671                  Иркутская область, Иркутск, Пулковский переулок, 28
# 43                           Иркутская область, Иркутск, улица Костычева
# 51   Иркутская область, Иркутск, Затон кв-л, улица Набережная Иркута, 23
# 140                      Иркутская область, Иркутск, улица Костычева, 28
#
#       area  floor    price repair                                     link
# 508  39.60   4/16  5543370    NaN  https://www.cian.ru/sale/flat/298600132
# 671  36.87  11/15  4800000    NaN  https://www.cian.ru/sale/flat/296464654
# 43   66.10   2/12  7204900    NaN  https://www.cian.ru/sale/flat/295895639
# 51   61.59   6/19  7729545    NaN  https://www.cian.ru/sale/flat/293746937
# 140  47.90   7/12  5556400    NaN  https://www.cian.ru/sale/flat/300151520

# %% [markdown]
# ### 2. Предобработка данных
# Перед работой с данными необходимо произвести следующие изменения и анализ данных:
# ##### 1. Создадим дополнительные столбцы
# Добавим столбцы "Этажей в доме" и столбец "Цена за квадратный метр":
# 1. Разделим столбец "floor": Возьмем из столбца "floor" информацию за знаком "/" и добавим столбец "floor_all" с данными о количестве этажей в доме
# 2. Добавим данные о цене за квадратный метр в новый столбец "price_square"
#
#
# ##### 2. Изменим типы объектов в следующих столбцах:
# *rooms* - изменить на тип объекта int\
# *floor* - изменить на int
#
# ##### 3. Работа с пропусками и дубликатами в данных.
# 1. Определим количество пропущенных значениях в столбцах и если есть пропуски, то для дальнейшей работы необходимо их убрать, заменив их на подходящие по логике данные.
# 2. Проверим данные на дубликаты по столбцам "Адрес" и "ID" - там не должны быть дубли, если они будут то строки необходимо удалить

# %% [markdown]
# #### Разделим столбец "floor" и добавим столбец "price_square" с данными о цене за квадратный метр

# %%
# добавим столбец 'floor_all'
data['floor_all'] = data['floor'].str.split('/').str.get(1)
data['floor'] = data['floor'].str.split('/').str.get(0)
data['price_square'] = (data['price'] / data['area'])/1000 # создадим столбец "price_square" с данными о цене за кв.м. и 
data['price'] = data['price']/1000000  # поделим результат на 100 для лучшего восприятия цены

# %%
data['price'] = data['price'].round(1) #  округлим числа до десятых
data['price_square'] = data['price_square'].round(1)
data.sample(5)
# Out:
#             ID rooms                            type       district  \
# 414  286808030     2  Продажа квартиры в новостройке    Октябрьский
# 648  299046888     1  Продажа квартиры в новостройке      Ленинский
# 249  299629851     1  Продажа квартиры в новостройке  Правобережный
# 501  298600525     1  Продажа квартиры в новостройке    Октябрьский
# 196  297248002     3  Продажа квартиры в новостройке  Правобережный
#
#                                                                          address  \
# 414                               Иркутская область, Иркутск, набережная Верхняя
# 648  Иркутская область, Иркутск, Ново-Ленино мкр, Первый Ленинский квартал ЖК, 1
# 249                                Иркутская область, Иркутск, улица Петрова, 16
# 501                                    Иркутская область, Иркутск, ИВАТУ городок
# 196                                 Иркутская область, Иркутск, Култукская улица
#
#       area floor  price repair                                     link  \
# 414  60.97    14   11.5    NaN  https://www.cian.ru/sale/flat/286808030
# 648  37.10     1    4.4    NaN  https://www.cian.ru/sale/flat/299046888
# 249  35.20    12    5.5    NaN  https://www.cian.ru/sale/flat/299629851
# 501  39.36    11    5.6    NaN  https://www.cian.ru/sale/flat/298600525
# 196  56.83    18   10.3    NaN  https://www.cian.ru/sale/flat/297248002
#
#     floor_all  price_square
# 414        18         188.7
# 648        13         117.5
# 249        16         156.0
# 501        16         141.8
# 196        19         181.0

# %% [markdown]
# Теперь данные в столбце "price" отображаются в млн., а данные в столбце "price_square" в тыс./за кв.м.

# %% [markdown]
# #### 2. Изменим типы объектов

# %%
# изменим тип данных для дальнейшего исследовани
data['rooms'] = data['rooms'].fillna(0).astype('int')
data['floor'] = data['floor'].fillna(0).astype('int')

# %%
display(data.sample(5))  # проверим изменненые данные
display(data.info())
# Out:
#             ID  rooms                            type       district  \
# 678  293369129      2                Продажа квартиры      Ленинский
# 261  287201742      1  Продажа квартиры в новостройке  Правобережный
# 166  292997518      1  Продажа квартиры в новостройке   Свердловский
# 72   293746813      2  Продажа квартиры в новостройке   Свердловский
# 494  298599664      1  Продажа квартиры в новостройке    Октябрьский
#
#                                                                  address  \
# 678                     Иркутская область, Иркутск, Березовый мкр, 140/2
# 261                  Иркутская область, Иркутск, улица Освобождения, 132
# 166                      Иркутская область, Иркутск, улица Румянцева, 48
# 72   Иркутская область, Иркутск, Затон кв-л, улица Набережная Иркута, 23
# 494                            Иркутская область, Иркутск, ИВАТУ городок
#
#        area  floor  price repair                                     link  \
# 678   62.40      9    4.9    NaN  https://www.cian.ru/sale/flat/293369129
# 261   46.40     11    5.6    NaN  https://www.cian.ru/sale/flat/287201742
# 166   37.70     15    6.2    NaN  https://www.cian.ru/sale/flat/292997518
# 72   105.91      5   11.9    NaN  https://www.cian.ru/sale/flat/293746813
# 494   40.65      2    5.5    NaN  https://www.cian.ru/sale/flat/298599664
#
#     floor_all  price_square
# 678         9          78.4
# 261        15         120.0
# 166        17         165.8
# 72         19         112.5
# 494        16         136.4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 763 entries, 0 to 762
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            763 non-null    int64
#  1   rooms         763 non-null    int32
#  2   type          763 non-null    object
#  3   district      763 non-null    object
#  4   address       763 non-null    object
#  5   area          763 non-null    float64
#  6   floor         763 non-null    int32
#  7   price         763 non-null    float64
#  8   repair        86 non-null     object
#  9   link          763 non-null    object
#  10  floor_all     763 non-null    object
#  11  price_square  763 non-null    float64
# dtypes: float64(3), int32(2), int64(1), object(6)
# memory usage: 65.7+ KB
# None

# %% [markdown]
# #### 3. Определим количество пропущенных значениях и исследуем на дубликаты в столбцах

# %%
# посчитаем пропуски
print('Количество дубликатов:', data.duplicated().sum())
print('Количие пропусков:')
data.isnull().sum()
# Out:
# Количество дубликатов: 0
# Количие пропусков:
# ID                0
# rooms             0
# type              0
# district          0
# address           0
# area              0
# floor             0
# price             0
# repair          677
# link              0
# floor_all         0
# price_square      0
# dtype: int64

# %% [markdown]
# Дубликатов данных нет.
# Пропуски в столбце с ремонтом и кол-вом комнат из-за отсутсивия информации - для работы с эти столбцом необходимо заменить пропущенные значения на 0 - как "нет информации о ремонте/комнатах":

# %%
# замена пропусков
data['repair'] = data['repair'].fillna(0)

# %% [markdown]
# ### 3. Анализ данных
# #### Исследуем количество объектов по категориям: район продаж, количество комнат, площадь, цена за квадратный метр. Построим визуализации.

# %%
# районы
display(data['district'].value_counts())
data['district'].hist();
# Out:
# district
# Октябрьский      200
# Ленинский        196
# Правобережный    195
# Свердловский     172
# Name: count, dtype: int64

# %% [markdown]
# Больше всего объявлений о продаже в Октябрьском районе

# %%
data['type'].unique() # посмотрим данные о типе квартир
# Out:
# array(['Продажа квартиры в новостройке', 'Продажа квартиры'], dtype=object)

# %% [markdown]
# Изменим столбец с данными о типе квартиры: заменим данные на "second" - вторичное жилье и "new" - новостройка.

# %%
data['type']
data = data.replace({'type':{'Продажа квартиры в новостройке':"new", 'Продажа квартиры': "second"}})
data.head()
# Out:
#           ID  rooms    type      district  \
# 0  300151528      2     new  Свердловский
# 1  297027698      2  second  Свердловский
# 2  300140904      2  second  Свердловский
# 3  295915593      1  second  Свердловский
# 4  295895678      3     new  Свердловский
#
#                                                address  area  floor  price  \
# 0          Иркутская область, Иркутск, улица Костычева  34.8      4    5.2
# 1   Иркутская область, Иркутск, улица Помяловского, 30  48.0      5    4.4
# 2      Иркутская область, Иркутск, улица Сергеева, 5/8  58.7      2    5.7
# 3  Иркутская область, Иркутск, улица Багратиона, 54/11  43.0      7    6.0
# 4          Иркутская область, Иркутск, улица Костычева  66.1     12    7.2
#
#           repair                                     link floor_all  \
# 0              0  https://www.cian.ru/sale/flat/300151528        12
# 1  Косметический  https://www.cian.ru/sale/flat/297027698         5
# 2     Евроремонт  https://www.cian.ru/sale/flat/300140904         4
# 3  Косметический  https://www.cian.ru/sale/flat/295915593         9
# 4              0  https://www.cian.ru/sale/flat/295895678        12
#
#    price_square
# 0         150.0
# 1          92.7
# 2          97.1
# 3         139.3
# 4         109.0

# %%
data['rooms'].unique()
# Out:
# array([2, 1, 3, 0, 4, 5])

# %%
data[data['rooms'] == 0]
# Out:
#             ID  rooms    type      district  \
# 10   290177501      0     new  Свердловский
# 12   290331577      0     new  Свердловский
# 75   294892664      0     new  Свердловский
# 76   294860880      0     new  Свердловский
# 77   294860878      0     new  Свердловский
# 78   295855794      0     new  Свердловский
# 80   299996076      0  second  Свердловский
# 367  299835129      0     new   Октябрьский
# 368  293372112      0     new   Октябрьский
# 373  298296152      0  second   Октябрьский
# 384  299808802      0     new   Октябрьский
# 396  296478530      0     new   Октябрьский
# 405  296478578      0     new   Октябрьский
# 409  270476578      0     new   Октябрьский
# 410  270476628      0     new   Октябрьский
# 411  294764320      0     new   Октябрьский
# 412  296478528      0     new   Октябрьский
# 435  300344533      0  second   Октябрьский
# 572  299872831      0     new     Ленинский
# 631  299997387      0  second     Ленинский
# 632  300005368      0  second     Ленинский
#
#                                                                   address  \
# 10                           Иркутская область, Иркутск, Союз Приорити ЖК
# 12                      Иркутская область, Иркутск, проезд Юрия Тена, 2/4
# 75                      Иркутская область, Иркутск, проезд Юрия Тена, 2/4
# 76                      Иркутская область, Иркутск, проезд Юрия Тена, 2/4
# 77                      Иркутская область, Иркутск, проезд Юрия Тена, 2/4
# 78                      Иркутская область, Иркутск, проезд Юрия Тена, 2/4
# 80                          Иркутская область, Иркутск, Радужный мкр, 112
# 367                      Иркутская область, Иркутск, улица Пискунова, 132
# 368                    Иркутская область, Иркутск, Байкальская улица, 418
# 373                    Иркутская область, Иркутск, улица Пискунова, 148/2
# 384                      Иркутская область, Иркутск, улица Пискунова, 132
# 396                      Иркутская область, Иркутск, улица Пискунова, 132
# 405                      Иркутская область, Иркутск, улица Пискунова, 134
# 409                    Иркутская область, Иркутск, Байкальская улица, 428
# 410                    Иркутская область, Иркутск, Байкальская улица, 428
# 411                    Иркутская область, Иркутск, Байкальская улица, 428
# 412                      Иркутская область, Иркутск, улица Пискунова, 132
# 435                  Иркутская область, Иркутск, Пограничный переулок, 1в
# 572                            Иркутская область, Иркутск, улица Мира, 32
# 631  Иркутская область, Иркутск, переулок Археолога Михаила Герасимова, 6
# 632  Иркутская область, Иркутск, переулок Археолога Михаила Герасимова, 6
#
#       area  floor  price         repair  \
# 10   44.21      9    8.3              0
# 12   55.26      8   11.1              0
# 75   60.25      8   16.3              0
# 76   60.25      9   16.3              0
# 77   68.32      9   18.4              0
# 78   68.33      5   18.4              0
# 80   26.00      7    3.9              0
# 367  39.69     10    7.2              0
# 368  48.93      7    9.9              0
# 373  29.10      4    4.0  Косметический
# 384  37.64     11    7.2              0
# 396  46.94     14    8.8              0
# 405  63.06     19    9.9              0
# 409  59.75      8   10.1              0
# 410  57.08      9   10.2              0
# 411  57.54      9   10.3              0
# 412  71.59     11   10.6              0
# 435  18.50      6    3.0     Евроремонт
# 572  37.32      4    5.4              0
# 631  27.80      3    3.7     Евроремонт
# 632  31.00     14    3.8              0
#
#                                         link floor_all  price_square
# 10   https://www.cian.ru/sale/flat/290177501         9         187.5
# 12   https://www.cian.ru/sale/flat/290331577         9         200.0
# 75   https://www.cian.ru/sale/flat/294892664         9         270.0
# 76   https://www.cian.ru/sale/flat/294860880         9         270.0
# 77   https://www.cian.ru/sale/flat/294860878         9         270.0
# 78   https://www.cian.ru/sale/flat/295855794         9         270.0
# 80   https://www.cian.ru/sale/flat/299996076        14         150.0
# 367  https://www.cian.ru/sale/flat/299835129        17         181.4
# 368  https://www.cian.ru/sale/flat/293372112         9         201.5
# 373  https://www.cian.ru/sale/flat/298296152        16         137.5
# 384  https://www.cian.ru/sale/flat/299808802        17         191.3
# 396  https://www.cian.ru/sale/flat/296478530        17         186.4
# 405  https://www.cian.ru/sale/flat/296478578        19         157.0
# 409  https://www.cian.ru/sale/flat/270476578         9         169.5
# 410  https://www.cian.ru/sale/flat/270476628         9         178.9
# 411  https://www.cian.ru/sale/flat/294764320         9         179.7
# 412  https://www.cian.ru/sale/flat/296478528        19         148.1
# 435  https://www.cian.ru/sale/flat/300344533         6         161.1
# 572  https://www.cian.ru/sale/flat/299872831        13         143.4
# 631  https://www.cian.ru/sale/flat/299997387        16         133.1
# 632  https://www.cian.ru/sale/flat/300005368        16         121.0

# %% [markdown]
# По полученным данным большенство квартир с кол-вом комнат = 0 это новостройки без ремонта. Остальные 5 квартир имеют площадь менее 31 квадрата - значит это студии. Оставим как есть.

# %%
display(data['rooms'].value_counts()) #посчитаем количество квартир в зависимости от количества комнат
data['rooms'].hist(figsize=(4,4)) #построим диаграмму
# Out:
# rooms
# 1    539
# 2    127
# 3     60
# 0     21
# 4     15
# 5      1
# Name: count, dtype: int64
# <Axes: >

# %%
#сгруппируем данные по району
data_district = data.pivot_table(index = 'district', values = 'ID', columns='rooms', aggfunc = 'count').reset_index().fillna(0)
display(data_district) 
display(data_district.info())
# Out:
# rooms       district     0      1     2     3    4    5
# 0          Ленинский   3.0  132.0  41.0  17.0  3.0  0.0
# 1        Октябрьский  11.0  140.0  30.0  15.0  4.0  0.0
# 2      Правобережный   0.0  168.0  11.0  11.0  5.0  0.0
# 3       Свердловский   7.0   99.0  45.0  17.0  3.0  1.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   district  4 non-null      object
#  1   0         4 non-null      float64
#  2   1         4 non-null      float64
#  3   2         4 non-null      float64
#  4   3         4 non-null      float64
#  5   4         4 non-null      float64
#  6   5         4 non-null      float64
# dtypes: float64(6), object(1)
# memory usage: 352.0+ bytes
# None

# %% [markdown]
# ### 4. Визуализация данных
# #### Визуализация данных по районам

# %%
# строим гистограммы 
fig = px.histogram(data_district, # загружаем данные 
                   x=[0, 1, 2, 3, 4, 5], # указываем столбец с данными для оси X 
                   y= 'district',
                   title='Распределение по районам') # указываем заголовок 
fig.update_layout(yaxis_title ='Районы') # подпись для оси X 
fig.update_layout(xaxis_title ='Количество комнат') # подпись для оси Y 
fig.show(); # выводим график
# Out:
# <div>                            <div id="9d5c014d-3f60-4f2e-b0ea-9ca3644079d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d5c014d-3f60-4f2e-b0ea-9ca3644079d1")) {                    Plotly.newPlot(                        "9d5c014d-3f60-4f2e-b0ea-9ca3644079d1",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=0\u003cbr\u003esum of value=%{x}\u003cbr\u003edistrict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"h","showlegend":true,"x":[3.0,11.0,0.0,7.0],"xaxis":"x","y":["\u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439","\u041e\u043a\u0442\u044f\u0431\u0440\u044c\u0441\u043a\u0438\u0439","\u041f\u0440\u0430\u0432\u043e\u0431\u0435\u0440\u0435\u0436\u043d\u044b\u0439","\u0421\u0432\u0435\u0440\u0434\u043b\u043e\u0432\u0441\u043a\u0438\u0439"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=1\u003cbr\u003esum of value=%{x}\u003cbr\u003edistrict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"h","showlegend":true,"x":[132.0,140.0,168.0,99.0],"xaxis":"x","y":["\u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439","\u041e\u043a\u0442\u044f\u0431\u0440\u044c\u0441\u043a\u0438\u0439","\u041f\u0440\u0430\u0432\u043e\u0431\u0435\u0440\u0435\u0436\u043d\u044b\u0439","\u0421\u0432\u0435\u0440\u0434\u043b\u043e\u0432\u0441\u043a\u0438\u0439"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=2\u003cbr\u003esum of value=%{x}\u003cbr\u003edistrict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"h","showlegend":true,"x":[41.0,30.0,11.0,45.0],"xaxis":"x","y":["\u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439","\u041e\u043a\u0442\u044f\u0431\u0440\u044c\u0441\u043a\u0438\u0439","\u041f\u0440\u0430\u0432\u043e\u0431\u0435\u0440\u0435\u0436\u043d\u044b\u0439","\u0421\u0432\u0435\u0440\u0434\u043b\u043e\u0432\u0441\u043a\u0438\u0439"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=3\u003cbr\u003esum of value=%{x}\u003cbr\u003edistrict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"3","offsetgroup":"3","orientation":"h","showlegend":true,"x":[17.0,15.0,11.0,17.0],"xaxis":"x","y":["\u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439","\u041e\u043a\u0442\u044f\u0431\u0440\u044c\u0441\u043a\u0438\u0439","\u041f\u0440\u0430\u0432\u043e\u0431\u0435\u0440\u0435\u0436\u043d\u044b\u0439","\u0421\u0432\u0435\u0440\u0434\u043b\u043e\u0432\u0441\u043a\u0438\u0439"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=4\u003cbr\u003esum of value=%{x}\u003cbr\u003edistrict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"4","offsetgroup":"4","orientation":"h","showlegend":true,"x":[3.0,4.0,5.0,3.0],"xaxis":"x","y":["\u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439","\u041e\u043a\u0442\u044f\u0431\u0440\u044c\u0441\u043a\u0438\u0439","\u041f\u0440\u0430\u0432\u043e\u0431\u0435\u0440\u0435\u0436\u043d\u044b\u0439","\u0421\u0432\u0435\u0440\u0434\u043b\u043e\u0432\u0441\u043a\u0438\u0439"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=5\u00 ...

# %% [markdown]
# В полученном результате видим преобладание объявлений о продаже однокомнатных квартир в любом из районов

# %%
# можем посмотреть колличество каких квартир продается, 
# новостроек или вторичного жилья, по районам
data_price4 = data.pivot_table(index = 'district', values = 'ID', columns='type', aggfunc = 'count').reset_index()
data_price4['%_new'] = 100*(data_price4['new'] / data_price4['new'].sum()).round(3)
data_price4['%_second'] = 100*(data_price4['second'] / data_price4['second'].sum()).round(3)

data_price4
# Out:
# type       district  new  second  %_new  %_second
# 0         Ленинский  162      34   24.6      32.4
# 1       Октябрьский  167      33   25.4      31.4
# 2     Правобережный  185      10   28.1       9.5
# 3      Свердловский  144      28   21.9      26.7

# %% [markdown]
# Новостроек много в Правобережном районе - 28%. А объявлений вторичного жилья больше в Ленинском районе - 32,4%.

# %%
# можем посмотреть колличество скольки комнатных квартир, 
# новостроек или вторичного жилья, в каких районах продается больше чем в остальных
data_price2 = data.pivot_table(index = ['district', 'rooms'], values = 'ID', columns='type', aggfunc = 'count')
data_price2
# Out:
# type                   new  second
# district      rooms
# Ленинский     0        1.0     2.0
#               1      122.0    10.0
#               2       32.0     9.0
#               3        7.0    10.0
#               4        NaN     3.0
# Октябрьский   0        9.0     2.0
#               1      137.0     3.0
#               2        9.0    21.0
#               3        9.0     6.0
#               4        3.0     1.0
# Правобережный 1      164.0     4.0
#               2        9.0     2.0
#               3        8.0     3.0
#               4        4.0     1.0
# Свердловский  0        6.0     1.0
#               1       93.0     6.0
#               2       31.0    14.0
#               3       11.0     6.0
#               4        3.0     NaN
#               5        NaN     1.0

# %% [markdown]
# #### Посмотрим заполнение данных в столбце с данными - цена за кв.метр

# %%
# цена за квартиру
data['price'].describe().round(3)
# Out:
# count    763.000
# mean       6.240
# std        2.825
# min        1.800
# 25%        5.150
# 50%        5.600
# 75%        6.000
# max       45.000
# Name: price, dtype: float64

# %%
# цена за квадратный метр
display(data['price_square'].describe().round(1))
data['price_square'].hist(bins=100);
# Out:
# count    763.0
# mean     139.3
# std       28.4
# min       67.3
# 25%      119.8
# 50%      140.0
# 75%      151.5
# max      346.2
# Name: price_square, dtype: float64

# %% [markdown]
#    Средняя цена за квадратный метр - 67.3 т.р./кв. А максиматльная сумма за квадрат - 346.2 т.р./кв Посмотрим эти объявления:

# %%
data[data['price_square'] == 67.3]
# Out:
#             ID  rooms    type   district  \
# 669  294011755      3  second  Ленинский
#
#                                             address  area  floor  price  \
# 669  Иркутская область, Иркутск, Алтайская улица, 2  71.3      2    4.8
#
#     repair                                     link floor_all  price_square
# 669      0  https://www.cian.ru/sale/flat/294011755         2          67.3

# %%
data[data['price_square'] == 346.2]
# Out:
#             ID  rooms    type     district  \
# 434  297865294      3  second  Октябрьский
#
#                                                     address   area  floor  \
# 434  Иркутская область, Иркутск, улица Карла Либкнехта, 201  130.0     17
#
#      price        repair                                     link floor_all  \
# 434   45.0  Дизайнерский  https://www.cian.ru/sale/flat/297865294        17
#
#      price_square
# 434         346.2

# %% [markdown]
# Для просмотра квартир по районам с ценой за квадратный метр создадим категории в датафрейме data - столбец cat_pricesquare:
#
# 0–119 — 'менее 119 т.р за кв.м';\
# 120–140 — 'от 120 до 140 т.р за кв.м';\
# 141–152 — 'от 141 до 152 т.р за кв.м';\
# 152 и выше — 'свыше 152 т.р за кв.м'.

# %%
# создадим функцию для категорий по цене за кв.м.
def cat_pricesquare(income):
    try:
        if 0 <= income <= 119:
            return 'менее 119 т.р за кв.м'
        elif 120 <= income <= 140:
            return 'от 120 до 140 т.р за кв.м'
        elif 141 <= income <= 152:
            return 'от 141 до 152 т.р за кв.м'
        elif income >= 153:
            return 'свыше 152 т.р за кв.м'
    except:
        pass

# %%
# создадим столбец и применю функцию
data['cat_pricesquare'] = data['price_square'].apply(cat_pricesquare)
display(data.sample(5))
# Out:
#             ID  rooms    type       district  \
# 562  298599474      1     new    Октябрьский
# 701  296464692      1     new      Ленинский
# 591  285801088      1     new      Ленинский
# 182  299645715      2  second  Правобережный
# 746  296464621      2     new      Ленинский
#
#                                                    address   area  floor  \
# 562  Иркутская область, Иркутск, ИВАТУ городок, Авиатор ЖК  39.60      7
# 701    Иркутская область, Иркутск, Пулковский переулок, 28  40.57      2
# 591    Иркутская область, Иркутск, Иркутск-2 мкр, Зенит ЖК  38.29      2
# 182       Иркутская область, Иркутск, Советская улица, 113  43.10      4
# 746    Иркутская область, Иркутск, Пулковский переулок, 28  44.59      1
#
#      price         repair                                     link floor_all  \
# 562    5.7              0  https://www.cian.ru/sale/flat/298599474        16
# 701    5.0              0  https://www.cian.ru/sale/flat/296464692        15
# 591    5.3              0  https://www.cian.ru/sale/flat/285801088        13
# 182    5.4  Косметический  https://www.cian.ru/sale/flat/299645715         5
# 746    5.5              0  https://www.cian.ru/sale/flat/296464621        15
#
#      price_square            cat_pricesquare
# 562         143.8  от 141 до 152 т.р за кв.м
# 701         123.2  от 120 до 140 т.р за кв.м
# 591         138.5  от 120 до 140 т.р за кв.м
# 182         125.1  от 120 до 140 т.р за кв.м
# 746         123.3  от 120 до 140 т.р за кв.м

# %%
# создадим сводную таблицу по кол-ву обявлений
data_price5 = data.pivot_table(index = 'district', values = 'ID', columns='cat_pricesquare', aggfunc = 'count').reset_index()
data_price5
# Out:
# cat_pricesquare       district  менее 119 т.р за кв.м  \
# 0                    Ленинский                     91
# 1                  Октябрьский                      7
# 2                Правобережный                     12
# 3                 Свердловский                     77
#
# cat_pricesquare  от 120 до 140 т.р за кв.м  от 141 до 152 т.р за кв.м  \
# 0                                       77                         12
# 1                                       28                         73
# 2                                       52                         96
# 3                                       37                         12
#
# cat_pricesquare  свыше 152 т.р за кв.м
# 0                                    8
# 1                                   77
# 2                                   35
# 3                                   46

# %% [markdown]
# Дорогие квартиры, с ценой более 152тр. за кв.м. в Октябрьском районе, а в Ленинском - самые не дорогие с ценой до 119т.р. за кв.м.

# %%
# строим гистограммы 
fig = px.histogram(data_price5, # загружаем данные 
                   x=["менее 119 т.р за кв.м", "от 120 до 140 т.р за кв.м", "от 141 до 152 т.р за кв.м", "свыше 152 т.р за кв.м"], # указываем столбец с данными для оси X 
                   y= 'district',
                   title='Распределение по цене за квадрат') # указываем заголовок 
fig.update_layout(yaxis_title ='Районы') # подпись для оси X 
fig.update_layout(xaxis_title ='Количество комнат') # подпись для оси Y 
fig.show(); # выводим график
# Out:
# <div>                            <div id="ab839234-71df-48c5-9cbd-04c6ae1f6583" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab839234-71df-48c5-9cbd-04c6ae1f6583")) {                    Plotly.newPlot(                        "ab839234-71df-48c5-9cbd-04c6ae1f6583",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=\u043c\u0435\u043d\u0435\u0435 119 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c\u003cbr\u003esum of value=%{x}\u003cbr\u003edistrict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u043c\u0435\u043d\u0435\u0435 119 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u043c\u0435\u043d\u0435\u0435 119 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","offsetgroup":"\u043c\u0435\u043d\u0435\u0435 119 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","orientation":"h","showlegend":true,"x":[91,7,12,77],"xaxis":"x","y":["\u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439","\u041e\u043a\u0442\u044f\u0431\u0440\u044c\u0441\u043a\u0438\u0439","\u041f\u0440\u0430\u0432\u043e\u0431\u0435\u0440\u0435\u0436\u043d\u044b\u0439","\u0421\u0432\u0435\u0440\u0434\u043b\u043e\u0432\u0441\u043a\u0438\u0439"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=\u043e\u0442 120 \u0434\u043e 140 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c\u003cbr\u003esum of value=%{x}\u003cbr\u003edistrict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u043e\u0442 120 \u0434\u043e 140 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u043e\u0442 120 \u0434\u043e 140 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","offsetgroup":"\u043e\u0442 120 \u0434\u043e 140 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","orientation":"h","showlegend":true,"x":[77,28,52,37],"xaxis":"x","y":["\u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439","\u041e\u043a\u0442\u044f\u0431\u0440\u044c\u0441\u043a\u0438\u0439","\u041f\u0440\u0430\u0432\u043e\u0431\u0435\u0440\u0435\u0436\u043d\u044b\u0439","\u0421\u0432\u0435\u0440\u0434\u043b\u043e\u0432\u0441\u043a\u0438\u0439"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=\u043e\u0442 141 \u0434\u043e 152 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c\u003cbr\u003esum of value=%{x}\u003cbr\u003edistrict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u043e\u0442 141 \u0434\u043e 152 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u043e\u0442 141 \u0434\u043e 152 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","offsetgroup":"\u043e\u0442 141 \u0434\u043e 152 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","orientation":"h","showlegend":true,"x":[12,73,96,12],"xaxis":"x","y":["\u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439","\u041e\u043a\u0442\u044f\u0431\u0440\u044c\u0441\u043a\u0438\u0439","\u041f\u0440\u0430\u0432\u043e\u0431\u0435\u0440\u0435\u0436\u043d\u044b\u0439","\u0421\u0432\u0435\u0440\u0434\u043b\u043e\u0432\u0441\u043a\u0438\u0439"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"variable=\u0441\u0432\u044b\u0448\u0435 152 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c\u003cbr\u003esum of value=%{x}\u003cbr\u003edistrict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u0441\u0432\u044b\u0448\u0435 152 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0441\u0432\u044b\u0448\u0435 152 \u0442.\u0440 \u0437\u0430 \u043a\u0432.\u043c","offse ...

# %% [markdown]
# ## Вывод:
# * Больше всего объявлений о продаже в Октябрьском районе
# * Преобладание объявлений о продаже однокомнатных квартир в любом из районов
# * Новостроек много в Правобережном районе - 28%. А объявлений вторичного жилья больше в Ленинском районе - 32,4%.
# * Дорогие квартиры, с ценой более 152тр. за кв.м. в Октябрьском районе, а в Ленинском - самые не дорогие с ценой до 119т.р. за кв.м.
#
# #### По последней визуализации видно, что количество предложений недорогих квартир в Ленинском и Свердловском районе. А преобладание более дорогих квартир от 152тр за кв.м. - в Октябрьском районе. Из чего следует вывод, что цена за квадратный метр зависит от района продажи
